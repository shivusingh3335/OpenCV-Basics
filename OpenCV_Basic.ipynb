# %%
# !cd ..

# %%
ls

# %%
# %cd drive/My\ Drive/Colab\ Notebooks/image_reco/

# %%
ls

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image= cv2.imread("pic1.jpg")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=228x221 at 0x7F85BF8091D0>

# %%
#writing the image
cv2.imwrite("image name.jpg",image)

# %% [markdown]
# Changing the color of the image

# %%
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=228x221 at 0x7F85BDF23C18>

# %%
gray=cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=RGB size=228x221 at 0x7F85BDF23C50>

# %% [markdown]
# Image resize

# %%
img_resize=cv2.resize(image,(150,150))
cv2_imshow(img_resize)
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F85BDF3D358>

# %% [markdown]
# Image rotation

# %%
rows,cols=image.shape[:2]
M=cv2.getRotationMatrix2D((cols/2,rows/2),180,1)
dst=cv2.warpAffine(image,M,(cols,rows))
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=228x221 at 0x7F85BDF08080>

# %% [markdown]
# Image Translation

# %%
import numpy as np

# %%
height, width = image.shape[:2] 
quarter_height, quarter_width = height / 4, width / 4
T = np.float32([[1, 0, quarter_width], [0, 1, quarter_height]])
img_translation = cv2.warpAffine(image, T, (width, height)) 
cv2_imshow(img_translation)
# Out:
# <PIL.Image.Image image mode=RGB size=228x221 at 0x7F85BDCA9208>

# %% [markdown]
# Edge Detection

# %%
edge=cv2.Canny(image,300,300)
cv2_imshow(edge)
# Out:
# <PIL.Image.Image image mode=L size=228x221 at 0x7F85BDD804A8>
